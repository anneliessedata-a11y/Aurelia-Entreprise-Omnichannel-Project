# %% [markdown]
# # Campaign ROI and Conversion
#
# Campaign-level exposure, conversion, revenue and ROI proxy. This is attribution analysis, not causal lift.

# %%
# Campaign ROI and conversion analysis
