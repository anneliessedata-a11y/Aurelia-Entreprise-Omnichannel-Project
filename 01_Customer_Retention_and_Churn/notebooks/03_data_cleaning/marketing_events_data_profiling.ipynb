# %%
import pandas as pd  # Import pandas for data profiling.
df = pd.read_csv("raw_data/marketing_events.csv")  # Load the raw dataset.
print(df.shape)  # Display dataset dimensions.
print(df.dtypes)  # Display column data types.
print(df.isna().sum())  # Count missing values.
print(df.nunique())  # Count unique values.
print(df.describe(include="all"))  # Generate descriptive statistics.
