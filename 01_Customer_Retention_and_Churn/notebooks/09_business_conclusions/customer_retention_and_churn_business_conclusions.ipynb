# %%
print("BUSINESS INSIGHT: Customer Retention and Churn")  # Restate the decision context.
print("Conclusion structure: evidence → implication → action → limitation")  # Set a disciplined consulting conclusion.

# %%
conclusion_fields = ["Observed evidence","Business implication","Potential action","Model or analysis limitation","Next validation step"]  # Define evidence-led conclusion fields.
for field in conclusion_fields: print(f"- {field}")  # Display the final review structure.
print("Final recommendations should follow observed evidence, not assumptions.")  # Keep recommendations evidence-based.
