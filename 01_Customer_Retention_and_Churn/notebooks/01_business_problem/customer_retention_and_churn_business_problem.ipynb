# %%
print("BUSINESS INSIGHT: Customer Retention and Churn")  # Identify the business decision being supported.
print("PROBLEM: Identify customer behaviours associated with inactivity and churn.")  # Frame the operational problem.
print("ANALYTICAL LENS: retention, repeat purchase, payment friction, service experience")  # Define the evidence expected from the data.
print("Approach: audit → diagnose → engineer → analyse → model → advise")  # Show the end-to-end consulting workflow.
# Out:
# BUSINESS INSIGHT: Customer Retention and Churn
# PROBLEM: Identify customer behaviours associated with inactivity and churn.
# ANALYTICAL LENS: retention, repeat purchase, payment friction, service experience
# Approach: audit → diagnose → engineer → analyse → model → advise

# %%
questions = ["What is happening?","Where is it happening?","What may explain it?","What can be predicted or prioritised?","What evidence should inform action?"]  # Define the diagnostic questions.
for question in questions: print(f"- {question}")  # Display the investigation sequence.
# Out:
# - What is happening?
# - Where is it happening?
# - What may explain it?
# - What can be predicted or prioritised?
# - What evidence should inform action?

# %%
kpis = ["volume","rate","value","frequency","time","quality","risk"]  # Define reusable KPI dimensions.
print("Candidate KPI dimensions:", ", ".join(kpis))  # Set the initial measurement frame.
print("KPI definitions must be validated against dataset fields.")  # Avoid assuming business meaning before inspection.
# Out:
# Candidate KPI dimensions: volume, rate, value, frequency, time, quality, risk
# KPI definitions must be validated against dataset fields.

# %%
hypotheses = ["Observed performance differs across customer or operational segments.","Transaction behaviour contains measurable drivers of the business outcome.","Data-quality issues may distort observed performance."]  # Set testable hypotheses for investigation.
for hypothesis in hypotheses: print(f"- {hypothesis}")  # Make the diagnostic logic visible.
# Out:
# - Observed performance differs across customer or operational segments.
# - Transaction behaviour contains measurable drivers of the business outcome.
# - Data-quality issues may distort observed performance.
