# %% [markdown]
# # Payment Risk and Fraud
#
# The supplied data has payment status, not a confirmed fraud label. The implemented model therefore predicts payment failure and does not claim fraud detection.

# %%
# See project model script.
